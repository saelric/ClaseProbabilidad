# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datos = pd.read_csv('/home/sandy/Probabilidad y estadistica/Datasets/football.csv',
                    usecols={'Team','W','L','D'},
                    index_col=[0])

# %%
datos.plot(kind='bar',figsize=(20,6), colormap="Spectral")

# %%
datos[['W','L']].plot(kind='area', stacked=False)

# %%
plt.pie(datos['W'], labels = datos.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ffa094a9358>,
# ...
#  [Text(1.05319,0.317461,'Arsenal'),
#   Text(0.721197,0.830587,'Liverpool'),
#   Text(0.191013,1.08329,'Manchester_U'),
#   Text(-0.35871,1.03987,'Newcastle'),
#   Text(-0.766793,0.788688,'Leeds'),
#   Text(-1.01085,0.433791,'Chelsea'),
#   Text(-1.09888,0.0495281,'West_Ham'),
#   Text(-1.06332,-0.281709,'Aston_Villa'),
#   Text(-0.93677,-0.576595,'Tottenham'),
#   Text(-0.730504,-0.822413,'Blackburn'),
#   Text(-0.484434,-0.987585,'Southampton'),
#   Text(-0.203199,-1.08107,'Middlesbrough'),
#   Text(0.0680806,-1.09789,'Fulham'),
#   Text(0.311526,-1.05497,'Charlton'),
#   Text(0.55,-0.952628,'Everton'),
#   Text(0.748838,-0.805755,'Bolton'),
#   Text(0.90284,-0.628395,'Sunderland'),
#   Text(1.01567,-0.422382,'Ipswich'),
#   Text(1.07748,-0.221428,'Derby'),
#   Text(1.09826,-0.0618983,'Leicester')])

# %%
plt.plot(datos['W'],datos['L'],'>',color="blue")
plt.ylabel('Perdidos')
plt.xlabel('Partidos Ganados')
# Out:
# Text(0.5,0,'Partidos Ganados')

# %%
al = np.random.randint(0,101,(10,2))

# %%
plt.imshow(al)

# %%
plt.imshow(datos.corr(), cmap='hot')
